# %% [markdown]
# <a href="https://colab.research.google.com/github/Catz94/Practical-Discrete-Mathematics/blob/master/Picture_convert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install mediapipe
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.1/36.1 MB 26.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# Scale the image

# %%
#get the info
from PIL import Image
import matplotlib.pyplot as plt
import requests
from io import BytesIO

# Load the image
url = 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/80/Wikipedia-logo-v2.svg/225px-Wikipedia-logo-v2.svg.png'  # Replace with your image URL
response = requests.get(url)
img = Image.open(BytesIO(response.content))

# Display the original image
plt.imshow(img)
plt.title('Original Image')
plt.axis('off')
plt.show()

# Scale the image
new_size = (10, 10)  # Replace with your desired size
scaled_img = img.resize(new_size)

# Display the scaled image
plt.imshow(scaled_img)
plt.title('Scaled Image')
plt.axis('off')
plt.show()

# %% [markdown]
# Tranpose the image 90 degree

# %%
from PIL import Image
import matplotlib.pyplot as plt
import requests
from io import BytesIO

# Load the image
url = 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/80/Wikipedia-logo-v2.svg/225px-Wikipedia-logo-v2.svg.png'
response = requests.get(url)
img = Image.open(BytesIO(response.content))

# Display the original image
plt.imshow(img)
plt.title('Original Image')
plt.axis('off')
plt.show()

# Rotate the image 90 degrees counter-clockwise
rotated_img = img.transpose(Image.ROTATE_90)

# Display the rotated image
plt.imshow(rotated_img)
plt.title('Rotated Image (90° Counter-Clockwise)')
plt.axis('off')
plt.show()

# %% [markdown]
# https://vignette.wikia.nocookie.net/gameofthrones/images/2/25/707_Daenerys_Profil.jpg/revision/latest?cb=20170829215522&path-prefix=de  remove the background of the image. ONLY maintain the character

# %%
import cv2
import mediapipe as mp
import matplotlib.pyplot as plt

# Load the Mediapipe Selfie Segmentation
mp_selfie_segmentation = mp.solutions.selfie_segmentation.SelfieSegmentation(model_selection=1)

# Read the image
image = cv2.imread("input_image.jpg")
image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Process the image
result = mp_selfie_segmentation.process(image_rgb)

# Create a mask and apply it
mask = result.segmentation_mask > 0.1  # Threshold for background removal
image_no_bg = image_rgb.copy()
image_no_bg[~mask] = [255, 255, 255]  # Set background to white

# Display the result
plt.imshow(image_no_bg)
plt.axis("off")
plt.show()

# %% [markdown]
# Change the image colour to gray tone.

# %%
import cv2
import matplotlib.pyplot as plt

# Read the image
image = cv2.imread("input_image.jpg")

# Convert the image to grayscale using OpenCV's efficient cvtColor function
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Display the grayscale image
plt.imshow(gray_image, cmap='gray')  # Use 'gray' colormap for accurate grayscale display
plt.axis("off")
plt.show()

# %% [markdown]
# Find 2 creative common images online. Combine these 2 images side by side vertically. Export it as Jpg

# %%
import cv2
import matplotlib.pyplot as plt

# Read the images
image1 = cv2.imread("input_image.jpg")
image2 = cv2.imread("84693449.png")

# Ensure both images have the same number of channels (e.g., RGB)
if len(image1.shape) == 2:  # If image1 is grayscale
    image1 = cv2.cvtColor(image1, cv2.COLOR_GRAY2BGR)
if len(image2.shape) == 2:  # If image2 is grayscale
    image2 = cv2.cvtColor(image2, cv2.COLOR_GRAY2BGR)

# Resize images to have the same width (optional)
width = min(image1.shape[1], image2.shape[1])
image1 = cv2.resize(image1, (width, int(image1.shape[0] * width / image1.shape[1])))
image2 = cv2.resize(image2, (width, int(image2.shape[0] * width / image2.shape[1])))

# Combine images vertically
combined_image = cv2.vconcat([image1, image2])

# Display the combined image
plt.imshow(cv2.cvtColor(combined_image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# Save the combined image as a JPG file
cv2.imwrite("combined_image.jpg", combined_image)
# Out:
# True
